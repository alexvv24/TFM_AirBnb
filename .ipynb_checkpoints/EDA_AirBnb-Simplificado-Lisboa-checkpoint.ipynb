# %% [markdown]
# ## Limpieza de los datos de *AirBnb*

# %% [markdown]
# En la [web](http://insideairbnb.com/get-the-data.html) tenemos 7 archivos diferentes sobre los establecimientos AirBnb en Madrid.  Estos archivos son:
# * listings.csv.gz
# * calendar.csv.gz
# * reviews.csv.gz
# * listings.csv
# * reviews.csv
# * neighbourhoods.csv
# * neighbourhoods.geojson
#
# Los que tienen la extensión .gz son datos sin agrupar que vienen en formato comprimido mientras que los que no la tienen son datos agregados.  Los dos últimos tienen la función de geolocalizar los apartamentos en el mapa.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
df_feb = pd.read_csv('Data/Lisboa/listings0.csv.gz',compression='gzip',low_memory=False)

# %%
#vemos la estructura de los datos 
df_feb.shape
# Out:
# (22588, 106)

# %%
#Todas las columnas están en minúsculas y no hay espacios
df_feb.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  24056  https://www.airbnb.com/rooms/24056  20190123134024   2019-01-23
# 1  25659  https://www.airbnb.com/rooms/25659  20190123134024   2019-01-23
# 2  26993  https://www.airbnb.com/rooms/26993  20190123134024   2019-01-23
# 3  28066  https://www.airbnb.com/rooms/28066  20190123134024   2019-01-23
# 4  29138  https://www.airbnb.com/rooms/29138  20190123134024   2019-01-23
#
#                                         name  \
# 0                              Linda-a-Velha
# 1  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama
# 2         Small nice apartment in the center
# 3                              ear the birds
# 4              Room for rent in shared house
#
#                                              summary  \
# 0                                                NaN
# 1  Heart of Alfama! Sunny Charming 1 Bedroom apar...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                space  \
# 0  A comfortable apartment with pool during the s...
# 1  Charming sunny apartment in the heart of Alfam...
# 2  Apartment for single or couple, 5 minutes walk...
# 3  traditional farm house in a quiet place where ...
# 4  05 minutes from city center by subway, 10 minu...
#
#                                          description experiences_offered  \
# 0  A comfortable apartment with pool during the s...                none
# 1  Heart of Alfama! Sunny Charming 1 Bedroom apar...                none
# 2  Apartment for single or couple, 5 minutes walk...                none
# 3  traditional farm house in a quiet place where ...                none
# 4  05 minutes from city center by subway, 10 minu...                none
#
#                                neighborhood_overview        ...          \
# 0                                                NaN        ...
# 1  Alfama is the oldest and most picturesque quar...        ...
# 2  this is one of the best neighborhoods in Lisbo...        ...
# 3                                                NaN        ...
# 4                                                NaN        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                t                        f                     moderate
# 2                f                        f  strict_14_with_grace_period
# 3                f                        f                     flexible
# 4                f                        f                     flexible
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               1.66
# 2                                            0               0.06
# 3                                            0                NaN
# 4                                            0                NaN
#
# [5 rows x 106 columns]

# %% [markdown]
# El **primer criterio** utilizado para simplificar la información contenida en la tabla es el de encontrar aquellas columnas prescindibles.

# %%
#Comprobamos chequeando la URL que significa cada columna y eliminamos las que son solo de consulta, 

a_borrar_consulta = ['listing_url','host_url']

#campos de texto sin relevancia, variables redundantes o URL`s que no nos sirven para el análisis. 
#Normalmente los campos de texto no vienen predeterminados por AirBnb y por tanto no tienen formato establecido.

a_borrar_texto = ['summary','space','neighborhood_overview','notes'
                     ,'transit','access','interaction','house_rules']
a_borrar_redundantes = ['scrape_id','calendar_last_scraped','jurisdiction_names','country'
                        ,'country_code','street','market']
a_borrar_urls = ['thumbnail_url','picture_url','medium_url','xl_picture_url','host_thumbnail_url','host_picture_url']

#Las siguientes columnas son eliminadas por el desconocimiento del método de cálculo o por no comprender que significan

a_borrar_desconocidas = ['is_location_exact','maximum_maximum_nights','maximum_minimum_nights','minimum_minimum_nights'
                        ,'minimum_minimum_nights','minimum_maximum_nights','is_business_travel_ready',
                         'host_verifications','host_identity_verified']
#Las siguientes hacen referencia al método de scrapping o están condicionadas por el momento concreto en el que se hizo

a_borrar_scrapping = ['maximum_nights','minimum_nights','calendar_updated','has_availability']

#Por último, estos requerimientos no son necesarios:

a_borrar_irrelevantes = ['require_guest_profile_picture','require_guest_phone_verification']

# %%
#Juntamos todas las columnas, las eliminamos y comprobamos cuánto se han reducido
Useless = a_borrar_texto+a_borrar_redundantes+a_borrar_urls+a_borrar_desconocidas+a_borrar_scrapping+a_borrar_irrelevantes
df_feb.drop(Useless,axis=1,inplace=True)
df_feb.shape
# Out:
# (22588, 71)

# %% [markdown]
# El **segundo criterio** para reducir las dimensiones es eliminar aquellas columnas que contengan al menos un 30% de nulos, ya que no serán útiles con tanta información perdida.

# %%
#Representamos gráficamente el % de nulos de las columnas restantes
missing = df_feb.isnull().sum()/df_feb.shape[0]
ax = missing.plot(kind='bar',figsize=(22,7))
ax.set_xlabel('columnas',fontsize=18)
ax.set_ylabel('% fatos que faltan',fontsize=18)
ax.set_title('Selección de columnas',fontsize=22)
plt.show()

# %%
nulos_feb = missing.loc[missing > 0.3].index
nulos_lista_feb = list(nulos_feb)
nulos_lista_feb
# Out:
# ['host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_neighbourhood',
#  'square_feet',
#  'weekly_price',
#  'monthly_price']

# %%
#Tenemos 62 columnas para realizar el análisis, pudiendo ser reducidas en el futuro en caso de ser considerado.
df_feb.drop(nulos_lista_feb, axis = 1, inplace = True)
df_feb.shape
# Out:
# (22588, 63)

# %%
#Obtenemos el % de nulos para cada periodo en Madrid, la segunda parte de la función se utiliza
#para eliminar aquellos campos que no se usaban en el momento del scrapping.
def saca_nulos(file):
    try:
        df_month = pd.read_csv(file,compression='gzip',low_memory=False)
        global Useless
        df_month.drop(Useless,axis=1,inplace = True)
        missing = df_month.isnull().sum()/df_month.shape[0]
        nulos_month = missing.loc[missing > 0.3].index
        return list(nulos_month)
    except:
        df_month = pd.read_csv(file,compression='gzip',low_memory=False)
        global a_borrar_desconocidas
        a_borrar_desconocidas = ['is_location_exact','is_business_travel_ready',
                         'host_verifications','host_identity_verified']
        Useless = a_borrar_texto+a_borrar_redundantes+a_borrar_urls+a_borrar_desconocidas+a_borrar_scrapping+a_borrar_irrelevantes
        df_month.drop(Useless,axis=1,inplace = True)
        missing = df_month.isnull().sum()/df_month.shape[0]
        nulos_month = missing.loc[missing > 0.3].index
        return list(nulos_month)

# %%
filenames = ['Data/Lisboa/listings0.csv.gz','Data/Lisboa/listings1.csv.gz',
             'Data/Lisboa/listings2.csv.gz','Data/Lisboa/listings3.csv.gz',
             'Data/Lisboa/listings4.csv.gz','Data/Lisboa/listings5.csv.gz',
             'Data/Lisboa/listings6.csv.gz','Data/Lisboa/listings7.csv.gz',
             'Data/Lisboa/listings8.csv.gz','Data/Lisboa/listings9.csv.gz']
months = ['ene','dic','oct','sep','ago','jul','may','abr','ene']

# %%
lista_nulos_por_periodo = []
for f in filenames:
    a = saca_nulos(f)
    lista_nulos_por_periodo.append(a)

# %%
#Comprobamos que nos devuelve una lista de listas dividida por meses
lista_nulos_por_periodo
# Out:
# [['host_about',
#   'host_response_time',
#   'host_response_rate',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price'],
#  ['host_about',
#   'host_response_time',
#   'host_response_rate',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit'],
#  ['host_about',
#   'host_response_time',
#   'host_response_rate',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit'],
#  ['host_about',
#   'host_response_time',
#   'host_response_rate',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit',
#   'license'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit',
#   'license'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit',
#   'license'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit',
#   'license'],
#  ['host_about',
#   'host_acceptance_rate',
#   'host_neighbourhood',
#   'square_feet',
#   'weekly_price',
#   'monthly_price',
#   'security_deposit',
#   'license']]

# %%
lista_nulos_por_periodo[0]
# Out:
# ['host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_neighbourhood',
#  'square_feet',
#  'weekly_price',
#  'monthly_price']

# %%
#Como lo que nos interesa es borrar aquellas columnas que han sido más de un 30% nulas 
#debemos obtener los valores únicos en la lista
lista_demasiados_nulos = []
for i in range(len(filenames)):
    for x in lista_nulos_por_periodo[i]:
        if x not in lista_demasiados_nulos:
            lista_demasiados_nulos.append(x)

# %%
#Estas son las columnas que borraremos de cualquier periodo a analizar(en Madrid) para que los datos sean consistentes
lista_demasiados_nulos
# Out:
# ['host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_neighbourhood',
#  'square_feet',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'license']

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
df_feb.head()
# Out:
#       id                         listing_url last_scraped                                       name                                        description experiences_offered  host_id                                  host_url host_name host_since                      host_location host_is_superhost  host_listings_count  host_total_listings_count host_has_profile_pic              neighbourhood                       neighbourhood_cleansed neighbourhood_group_cleansed      city   state   zipcode      smart_location   latitude  longitude property_type        room_type  accommodates  bathrooms  bedrooms  beds  bed_type                                          amenities   price security_deposit cleaning_fee  guests_included extra_people  minimum_nights_avg_ntm  maximum_nights_avg_ntm  availability_30  availability_60  availability_90  availability_365  number_of_reviews  number_of_reviews_ltm first_review last_review  review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0  24056  https://www.airbnb.com/rooms/24056   2019-01-23                              Linda-a-Velha  A comfortable apartment with pool during the s...                none    95163   https://www.airbnb.com/users/show/95163  Patrícia 2010-03-17                           portugal                 f                  1.0                        1.0                    t                        NaN  Algs, Linda-a-Velha e Cruz Quebrada-Dafundo                       Oeiras    Oeiras  Lisbon      2795    Oeiras, Portugal  38.717143  -9.239672     Apartment     Private room             2        1.0       1.0   1.0  Real Bed  {"Cable TV",Wifi,"Wheelchair accessible",Pool,...  $84.00              NaN          NaN                1       $38.00                     2.0                    21.0               30               60               90               365                  0                      0          NaT         NaT                   NaN                     NaN                        NaN
# 1  25659  https://www.airbnb.com/rooms/25659   2019-01-23  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama  Heart of Alfama! Sunny Charming 1 Bedroom apar...                none   107347  https://www.airbnb.com/users/show/107347     Ellie 2010-04-12  New York, New York, United States                 t                  1.0                        1.0                    t                     Alfama                            Santa Maria Maior                       Lisboa    Lisboa  Lisboa  1100-571    Lisboa, Portugal  38.711671  -9.126964     Apartment  Entire home/apt             3        1.0       1.0   2.0  Real Bed  {TV,"Cable TV",Internet,Wifi,Kitchen,Heating,W...  $60.00          $150.00       $25.00                2        $0.00                     2.0                    21.0               27               57               87               356                 96                     20   2014-04-24  2018-11-09                  96.0                    10.0                       10.0
# 2  26993  https://www.airbnb.com/rooms/26993   2019-01-23         Small nice apartment in the center  Apartment for single or couple, 5 minutes walk...                none   111686  https://www.airbnb.com/users/show/111686      Hans 2010-04-21           Lisbon, Lisbon, Portugal                 f                  1.0                        1.0                    t  São Sebastião da Pedreira                               Avenidas Novas                       Lisboa    Lisbon  Lisbon      1050    Lisbon, Portugal  38.730747  -9.148240     Apartment  Entire home/apt             2        1.0       1.0   1.0  Real Bed  {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...  $80.00              NaN       $40.00                1        $0.00                     6.0                  1125.0                5               25               55                55                  6                      2   2010-07-12  2018-07-04                  87.0                    10.0                        8.0
# 3  28066  https://www.airbnb.com/rooms/28066   2019-01-23                              ear the birds  traditional farm house in a quiet place where ...                none   120855  https://www.airbnb.com/users/show/120855     Lucia 2010-05-08  Aveiras de Cima, Lisboa, Portugal                 f                  1.0                        1.0                    t                        NaN                              Aveiras de Cima                     Azambuja  Azambuja     NaN      2050  Azambuja, Portugal  39.146542  -8.915031         House     Private room             2        NaN       1.0   NaN  Real Bed                                                 {}  $53.00              NaN          NaN                1        $0.00                     1.0                   730.0               30               60               90               365                  0                      0          NaT         NaT                   NaN                     NaN                        NaN
# 4  29138  https://www.airbnb.com/rooms/29138   2019-01-23              Room for rent in shared house  05 minutes from city center by subway, 10 minu...                none   125304  https://www.airbnb.com/users/show/125304    Susana 2010-05-15           Lisbon, Lisbon, Portugal                 f                  1.0                        1.0                    t           São João de Deus                                      Areeiro                       Lisboa    Lisbon  Lisbon      1000    Lisbon, Portugal  38.736341  -9.137916     Apartment     Private room             1        NaN       1.0   NaN  Real Bed                                                 {}  $71.00              NaN          NaN                1        $0.00                     1.0                   730.0               30               60               90               365                  0                      0          NaT         NaT                   NaN                     NaN                        NaN
#
#    review_scores_checkin  review_scores_communication  review_scores_location  review_scores_value requires_license    license instant_bookable          cancellation_policy  calculated_host_listings_count  calculated_host_listings_count_entire_homes  calculated_host_listings_count_private_rooms  calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                    NaN                          NaN                     NaN                  NaN                t        NaN                f  strict_14_with_grace_period                               1                                            0                                             1                                            0                NaN
# 1                   10.0                         10.0                    10.0                 10.0                t  56539/AL.                t                     moderate                               1                                            1                                             0                                            0               1.66
# 2                   10.0                         10.0                    10.0                  9.0                t   66568/AL                f  strict_14_with_grace_period                               1                                            1                                             0                                            0               0.06
# 3                    NaN                          NaN                     NaN                  NaN                t        NaN                f                     flexible                               1                                            0                                             1                                            0                NaN
# 4                    NaN                          NaN                     NaN                  NaN                t        NaN                f                     flexible                               1                                            0                                             1                                            0                NaN

# %%
#Pasamos las fechas de formato texto a fecha
df_feb.last_scraped = pd.to_datetime(df_feb.last_scraped)
df_feb.host_since = pd.to_datetime(df_feb.host_since)
df_feb.first_review = pd.to_datetime(df_feb.first_review)
df_feb.last_review = pd.to_datetime(df_feb.last_review)
df_feb.last_scraped.dtype
# Out:
# dtype('<M8[ns]')

# %%
#Reemplazamos valores de la tabla por otros identificables
nulo_escondido = ['experiences_offered']

# %%
df_feb.drop(nulo_escondido, axis=1,inplace=True)

# %%
df_feb.shape
# Out:
# (22588, 62)

# %%
df_feb.neighbourhood_group_cleansed.value_counts()
# Out:
# Lisboa                   16529
# Cascais                   1999
# Sintra                    1262
# Mafra                     1256
# Oeiras                     397
# Lourinh                    341
# Torres Vedras              251
# Loures                     146
# Amadora                    125
# Odivelas                    95
# Alenquer                    55
# Cadaval                     47
# Vila Franca De Xira         32
# Azambuja                    23
# Sobral De Monte Agrao       22
# Arruda Dos Vinhos            8
# Name: neighbourhood_group_cleansed, dtype: int64
